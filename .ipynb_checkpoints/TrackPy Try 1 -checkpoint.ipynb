# %%
from astropy.io import fits as astro_fits  
from astropy.io.fits import getdata

import copy
import glob

import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy as np
from IPython.display import HTML

import astropy.table
from astropy.coordinates import SkyCoord
import astropy.units as u
from astropy.visualization import AsymmetricPercentileInterval, ImageNormalize, LogStretch 

#These packages are for Using TrackPy
import matplotlib.pyplot as plt 
import pandas as pd
from pandas import DataFrame, Series  # for convenience
import pims
import trackpy as tp

# %%
#This is to get our files from computer to Python
List_2 = glob.glob(r'C:\Users\14242\2022 Summer Internship\Sun Pics Part 2 (10 pics)\*')

# %%
List_2
# Out:
# ['C:\\Users\\14242\\2022 Summer Internship\\Sun Pics Part 2 (10 pics)\\11 Pic Sun.fits',
#  'C:\\Users\\14242\\2022 Summer Internship\\Sun Pics Part 2 (10 pics)\\12 Pic Sun.fits',
#  'C:\\Users\\14242\\2022 Summer Internship\\Sun Pics Part 2 (10 pics)\\13 Pic Sun.fits',
#  'C:\\Users\\14242\\2022 Summer Internship\\Sun Pics Part 2 (10 pics)\\14 Pic Sun.fits',
#  'C:\\Users\\14242\\2022 Summer Internship\\Sun Pics Part 2 (10 pics)\\15 Pic Sun.fits',
#  'C:\\Users\\14242\\2022 Summer Internship\\Sun Pics Part 2 (10 pics)\\16 Pic Sun.fits',
#  'C:\\Users\\14242\\2022 Summer Internship\\Sun Pics Part 2 (10 pics)\\17 Pic Sun.fits',
#  'C:\\Users\\14242\\2022 Summer Internship\\Sun Pics Part 2 (10 pics)\\18 Pic Sun.fits',
#  'C:\\Users\\14242\\2022 Summer Internship\\Sun Pics Part 2 (10 pics)\\19 Pic Sun.fits',
#  'C:\\Users\\14242\\2022 Summer Internship\\Sun Pics Part 2 (10 pics)\\20 Pic Sun.fits']

# %%
data_average = [] 
data_median = [] 
for Polar in List_2: 
    Polardata = getdata(Polar) 
    data_average.append(Polardata - np.average(Polardata)) 
    data_median.append(Polardata - np.median(Polardata))

# %%
data_average = np.array(data_average)

# %%
data_average.shape
# Out:
# (10, 4096, 4096)

# %%
np.average(data_average)
# Out:
# -2.3376197e-08

# %%
Arr=np.array(data_average)

# %%
Arr
# Out:
# array([[[-1.2833762 , -0.28337622, -1.2833762 , ..., -0.03337622,
#          -0.7833762 , -0.7833762 ],
#         [-2.0333762 , -0.03337622, -1.2833762 , ..., -0.5333762 ,
#          -2.7833762 , -0.5333762 ],
#         [-1.2833762 , -0.03337622, -1.0333762 , ..., -1.7833762 ,
#          -3.0333762 , -1.5333762 ],
#         ...,
#         [-2.0333762 , -1.7833762 , -0.28337622, ..., -2.0333762 ,
#          -1.0333762 , -0.7833762 ],
#         [-2.2833762 , -2.2833762 , -2.0333762 , ..., -1.2833762 ,
#          -1.2833762 , -2.0333762 ],
#         [-0.7833762 , -3.2833762 , -0.03337622, ..., -1.5333762 ,
#          -0.03337622, -2.0333762 ]],
#
#        [[-0.28525877, -1.2852588 , -1.2852588 , ..., -2.0352588 ,
#          -1.7852588 ,  1.2147412 ],
#         [-0.03525877, -0.03525877, -1.2852588 , ..., -0.53525877,
#          -0.78525877, -2.5352588 ],
#         [-1.2852588 , -2.0352588 , -1.0352588 , ..., -0.78525877,
#          -1.0352588 ,  0.46474123],
#         ...,
#         [-0.03525877,  0.21474123, -0.28525877, ..., -3.0352588 ,
#          -3.0352588 , -0.78525877],
#         [-4.285259  , -0.28525877, -2.0352588 , ..., -3.2852588 ,
#          -2.2852588 , -1.0352588 ],
#         [-2.7852588 , -1.2852588 , -1.0352588 , ..., -1.5352588 ,
#          -0.03525877, -2.0352588 ]],
#
#        [[-0.2889397 ,  1.7110603 , -1.2889397 , ..., -1.0389397 ,
#          -1.7889397 , -0.7889397 ],
#         [-1.0389397 , -0.03893971, -1.2889397 , ..., -1.5389397 ,
#          -2.7889397 ,  0.4610603 ],
#         [-2.2889397 , -1.0389397 ,  0.9610603 , ...,  0.21106029,
#          -2.0389397 , -1.5389397 ],
#         ...,
#         [-2.0389397 , -2.7889397 , -0.2889397 , ...,  0.9610603 ,
#          -0.03893971, -0.7889397 ],
#         [-2.2889397 , -0.2889397 , -1.0389397 , ..., -2.2889397 ,
#          -2.2889397 , -2.0389397 ],
#         [-1.7889397 , -1.2889397 , -2.0389397 , ..., -1.5389397 ,
#          -1.0389397 , -0.03893971]],
#
#        ...,
#
#        [[-0.27859712, -1.2785971 , -2.278597  , ..., -0.02859712,
#          -1.7785971 ,  0.22140288],
#         [-2.028597  , -1.0285971 ,  0.7214029 , ..., -0.5285971 ,
#          -2.778597  , -3.528597  ],
#         [-2.278597  , -2.028597  , -0.02859712, ..., -0.7785971 ,
#          -2.028597  , -1.5285971 ],
#         ...,
#         [-2.028597  , -1.7785971 , -2.278597  , ..., -3.028597  ,
#          -1.0285971 , -0.7785971 ],
#         [-1.2785971 , -1.2785971 , -3.028597  , ..., -2.278597  ,
#           1.7214029 , -0.02859712],
#         [ 0.22140288, -2.278597  , -2.028597  , ..., -1.5285971 ,
#          -4.028597  , -1.0285971 ]],
#
#        [[-1.2828904 , -1.2828904 , -1.2828904 , ..., -2.0328903 ,
#          -0.78289044, -1.7828904 ],
#         [-1.0328904 , -1.0328904 , -1.2828904 , ..., -0.53289044,
#          -2.7828903 , -1.5328904 ],
#         [-1.2828904 , -2.0328903 , -0.03289044, ..., -0.78289044,
#          -2.0328903 , -4.5328903 ],
#         ...,
#         [-1.0328904 ,  0.21710956, -0.28289044, ..., -0.03289044,
#           0.96710956,  0.21710956],
#         [-1.2828904 , -3.2828903 , -2.0328903 , ..., -3.2828903 ,
#          -1.2828904 , -2.0328903 ],
#         [ 0.21710956, -1.2828904 , -0.03289044, ..., -2.5328903 ,
#          -2.0328903 , -2.0328903 ]],
#
#        [[-3.28129   , -2.28129   ,  2.71871   , ..., -2.03129   ,
#          -0.7812902 , -0.7812902 ],
#         [-3.03129   , -2.03129   , -2.28129   , ..., -0.5312902 ,
#           0.21870983, -2.53129   ],
#         [-1.2812902 , -3.03129   , -0.03129017, ..., -2.78129   ,
#          -0.03129017, -3.53129   ],
#         ...,
#         [-2.03129   , -0.7812902 , -1.2812902 , ..., -1.0312902 ,
#          -2.03129   , -0.7812902 ],
#         [-2.28129   , -1.2812902 , -0.03129017, ..., -2.28129   ,
#          -0.28129017, -1.0312902 ],
#         [-2.78129   , -1.2812902 , -0.03129017, ..., -2.53129   ,
#          -2.03129   ,  0.9687098 ]]], dtype=float32)

# %%
Arr - Arr.mean()
# Out:
# array([[[-1.2833762 , -0.2833762 , -1.2833762 , ..., -0.03337619,
#          -0.7833762 , -0.7833762 ],
#         [-2.0333762 , -0.03337619, -1.2833762 , ..., -0.5333762 ,
#          -2.7833762 , -0.5333762 ],
#         [-1.2833762 , -0.03337619, -1.0333762 , ..., -1.7833762 ,
#          -3.0333762 , -1.5333762 ],
#         ...,
#         [-2.0333762 , -1.7833762 , -0.2833762 , ..., -2.0333762 ,
#          -1.0333762 , -0.7833762 ],
#         [-2.2833762 , -2.2833762 , -2.0333762 , ..., -1.2833762 ,
#          -1.2833762 , -2.0333762 ],
#         [-0.7833762 , -3.2833762 , -0.03337619, ..., -1.5333762 ,
#          -0.03337619, -2.0333762 ]],
#
#        [[-0.28525874, -1.2852588 , -1.2852588 , ..., -2.0352588 ,
#          -1.7852588 ,  1.2147412 ],
#         [-0.03525875, -0.03525875, -1.2852588 , ..., -0.53525877,
#          -0.78525877, -2.5352588 ],
#         [-1.2852588 , -2.0352588 , -1.0352588 , ..., -0.78525877,
#          -1.0352588 ,  0.46474126],
#         ...,
#         [-0.03525875,  0.21474126, -0.28525874, ..., -3.0352588 ,
#          -3.0352588 , -0.78525877],
#         [-4.285259  , -0.28525874, -2.0352588 , ..., -3.2852588 ,
#          -2.2852588 , -1.0352588 ],
#         [-2.7852588 , -1.2852588 , -1.0352588 , ..., -1.5352588 ,
#          -0.03525875, -2.0352588 ]],
#
#        [[-0.28893968,  1.7110603 , -1.2889397 , ..., -1.0389397 ,
#          -1.7889397 , -0.7889397 ],
#         [-1.0389397 , -0.03893969, -1.2889397 , ..., -1.5389397 ,
#          -2.7889397 ,  0.46106032],
#         [-2.2889397 , -1.0389397 ,  0.9610603 , ...,  0.21106032,
#          -2.0389397 , -1.5389397 ],
#         ...,
#         [-2.0389397 , -2.7889397 , -0.28893968, ...,  0.9610603 ,
#          -0.03893969, -0.7889397 ],
#         [-2.2889397 , -0.28893968, -1.0389397 , ..., -2.2889397 ,
#          -2.2889397 , -2.0389397 ],
#         [-1.7889397 , -1.2889397 , -2.0389397 , ..., -1.5389397 ,
#          -1.0389397 , -0.03893969]],
#
#        ...,
#
#        [[-0.2785971 , -1.2785971 , -2.278597  , ..., -0.02859709,
#          -1.7785971 ,  0.22140291],
#         [-2.028597  , -1.0285971 ,  0.7214029 , ..., -0.5285971 ,
#          -2.778597  , -3.528597  ],
#         [-2.278597  , -2.028597  , -0.02859709, ..., -0.7785971 ,
#          -2.028597  , -1.5285971 ],
#         ...,
#         [-2.028597  , -1.7785971 , -2.278597  , ..., -3.028597  ,
#          -1.0285971 , -0.7785971 ],
#         [-1.2785971 , -1.2785971 , -3.028597  , ..., -2.278597  ,
#           1.7214029 , -0.02859709],
#         [ 0.22140291, -2.278597  , -2.028597  , ..., -1.5285971 ,
#          -4.028597  , -1.0285971 ]],
#
#        [[-1.2828904 , -1.2828904 , -1.2828904 , ..., -2.0328903 ,
#          -0.78289044, -1.7828904 ],
#         [-1.0328904 , -1.0328904 , -1.2828904 , ..., -0.53289044,
#          -2.7828903 , -1.5328904 ],
#         [-1.2828904 , -2.0328903 , -0.03289042, ..., -0.78289044,
#          -2.0328903 , -4.5328903 ],
#         ...,
#         [-1.0328904 ,  0.21710959, -0.2828904 , ..., -0.03289042,
#           0.96710956,  0.21710959],
#         [-1.2828904 , -3.2828903 , -2.0328903 , ..., -3.2828903 ,
#          -1.2828904 , -2.0328903 ],
#         [ 0.21710959, -1.2828904 , -0.03289042, ..., -2.5328903 ,
#          -2.0328903 , -2.0328903 ]],
#
#        [[-3.28129   , -2.28129   ,  2.71871   , ..., -2.03129   ,
#          -0.7812902 , -0.7812902 ],
#         [-3.03129   , -2.03129   , -2.28129   , ..., -0.5312902 ,
#           0.21870986, -2.53129   ],
#         [-1.2812902 , -3.03129   , -0.03129015, ..., -2.78129   ,
#          -0.03129015, -3.53129   ],
#         ...,
#         [-2.03129   , -0.7812902 , -1.2812902 , ..., -1.0312902 ,
#          -2.03129   , -0.7812902 ],
#         [-2.28129   , -1.2812902 , -0.03129015, ..., -2.28129   ,
#          -0.28129014, -1.0312902 ],
#         [-2.78129   , -1.2812902 , -0.03129015, ..., -2.53129   ,
#          -2.03129   ,  0.9687098 ]]], dtype=float32)

# %%
Diff = Arr[2] - Arr[1]

# %%
Arr[2].shape
# Out:
# (4096, 4096)

# %%
Arr[1].shape
# Out:
# (4096, 4096)

# %%
Diff
# Out:
# array([[-3.6809444e-03,  2.9963191e+00, -3.6809444e-03, ...,
#          9.9631906e-01, -3.6809444e-03, -2.0036809e+00],
#        [-1.0036809e+00, -3.6809444e-03, -3.6809444e-03, ...,
#         -1.0036809e+00, -2.0036809e+00,  2.9963191e+00],
#        [-1.0036809e+00,  9.9631906e-01,  1.9963191e+00, ...,
#          9.9631906e-01, -1.0036809e+00, -2.0036809e+00],
#        ...,
#        [-2.0036809e+00, -3.0036809e+00, -3.6809444e-03, ...,
#          3.9963191e+00,  2.9963191e+00, -3.6809444e-03],
#        [ 1.9963191e+00, -3.6809444e-03,  9.9631906e-01, ...,
#          9.9631906e-01, -3.6809444e-03, -1.0036809e+00],
#        [ 9.9631906e-01, -3.6809444e-03, -1.0036809e+00, ...,
#         -3.6809444e-03, -1.0036809e+00,  1.9963191e+00]], dtype=float32)

# %%
Diff = [] 
for i in range (1,len(Arr)-1): 
    Diff.append(Arr[i+1]-Arr[i])

# %%
#Diff_1

# %%
Diff[0].shape
# Out:
# (4096, 4096)

# %%
Diff[0].max()
# Out:
# 537.49634

# %%
Diff[0].min()
# Out:
# -336.0037

# %%
plt.figure(figsize=(10,10))
plt.imshow(Diff[0],vmin = -1, vmax = 1)  
plt.colorbar()
plt.show()

# %%
#From here I will develop a code for TrackPy!!!!!!!!!!!!!!!

# %%
Arr[0]
# Out:
# array([[-1.2833762 , -0.28337622, -1.2833762 , ..., -0.03337622,
#         -0.7833762 , -0.7833762 ],
#        [-2.0333762 , -0.03337622, -1.2833762 , ..., -0.5333762 ,
#         -2.7833762 , -0.5333762 ],
#        [-1.2833762 , -0.03337622, -1.0333762 , ..., -1.7833762 ,
#         -3.0333762 , -1.5333762 ],
#        ...,
#        [-2.0333762 , -1.7833762 , -0.28337622, ..., -2.0333762 ,
#         -1.0333762 , -0.7833762 ],
#        [-2.2833762 , -2.2833762 , -2.0333762 , ..., -1.2833762 ,
#         -1.2833762 , -2.0333762 ],
#        [-0.7833762 , -3.2833762 , -0.03337622, ..., -1.5333762 ,
#         -0.03337622, -2.0333762 ]], dtype=float32)

# %%
#The graph gives us the grapg of the Arr
plt.figure(figsize=(10,10))
plt.imshow(Arr[0],vmin = -1, vmax = 1)  
plt.colorbar()
plt.show()

# %%
#TrackPy Images 
f = tp.locate(Arr[0], 11,invert = False )

# %%
#like this because it is super bright
tp.annotate(f,Arr[0]);

# %%
#This is to clean up the graph  
#Talk to Milo about the limits of the minmass
f = tp.locate(Arr[0], 11, invert = True, minmass = 50)

# %%
#This gives us the graph
tp.annotate(f,Arr[0]);

# %%
g = tp.locate(Arr[1], 11,invert = False, minmass=50 )

# %%
tp.annotate(g,Arr[1])
# Out:
# <AxesSubplot:>

# %%
# h = tp.locate(Diff[0], 11,invert = False, minmass=50 )

# %%
tp.annotate(h,Diff[0])
# Out:
# <AxesSubplot:>

# %%
#To much memeory
#Arr_Loo = tp.locate(Arr, 11,invert = False, minmass=50 )
